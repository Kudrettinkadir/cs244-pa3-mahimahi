# %% [markdown]
# <a href="https://colab.research.google.com/github/Kudrettinkadir/cs244-pa3-mahimahi/blob/master/Sklearn_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=200, centers=4, cluster_std=0.4, random_state=0)
import matplotlib.pyplot as plt

plt.scatter(X[:,0], X[:,1], s=20)
